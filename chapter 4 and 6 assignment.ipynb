# %%
#Alex Jolliff
#assignment 4.1
#Choose a number between 1 and 10 assigned to secret
import random
secret = random.randint(1,10)
#Alex Jolliff
#Choose another number between 1 and 10 and assign to guess
guess = random.randint(1,10)
#Alex Jolliff
#conditional test, "too low" if the guess is low", "too high" if it is high or "just right if it is correct"
if secret > guess:
    print("Too Low")
elif secret < guess:
    print("Too high")
else:
    print("Just right")
# Out:
# 5
# 2
# Too Low

# %%
#Alex Jolliff
# assignment 4.2
#getting item
item = input("Which item would you like to look up?")
#Alex Jolliff
#assigning true or false to small and green based on the item
if item == "Cherry":
    small = False
    green = False
elif item == "Pea":
    small = True
    green = True
elif item == "Watermelon": 
    small = False
    green = True
elif item == "Pumpkin":
    small = False
    true = False
else:
    print("invalid item, please select Cherry, Pea, Watermelon or Pumpkin")

#Alex Jolliff
#print the item and its size/greenness
print("A", item, end = " ")
if small == True:
    print("is small ", end = "")
else:
    print("is not small ", end = "")
if green == True:
    print("and it is green.", end = "")
else:
    print("and it is not green.")

# %%
#Alex Jolliff
#assignment 6.1
#for loop to print the items in a list
list = [3,2,1,0]
for item in list:
    print(item)
# Out:
# 3
# 2
# 1
# 0

# %%
#Alex Jolliff
#assignment 6/2
#Assign 7 to guess_me and 1 to number
guess_me = 7
number = 1
#While loop that runs until the guess and number are equal and increments up every time
while guess_me >= number:
    #print "too low" if its below 7
    if guess_me > number:
        print("too low")
    #print "found it" if it equals 7, since the while loop won't allow a number above 7 and the if above rules out lower numbers I didn't test for it again
    else:
        print("found it")
        break
    number += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it

# %%
#Alex Jolliff
#6.3
#Assign 5 to "guess_me"
guess_me = 5
# for loop iterating over range (10) to run 10 times
for num in range(10):
    #if the number is too small, print "too low", if it is equal print "found it" and break and if it is too big pring "oops"
    if num < guess_me:
        print("too low")
    elif num == guess_me:
        print("found it")
        break
    elif num > guess_me:
      print("oops")
        break
# Out:
# too low
