# %%
#Alex Jolliff
#things to do ch 7 and 9

# %%
#7.4, make a list called "things"  with Mozzarella, Cinderella and Slmonella as the elements
things = ["mozzarella", "cinderella", "salmonella"]
#7.5 capitalize cinderella, then print the list 
things[1] = things[1].capitalize()
print(things)
#answer to 7.5 prompt "Did it change the element in the list?" it did change the element in the list

#7.6 capitalize "mozzarella" to be all uppercase
things[0] = things[0].upper()
print(things)

#7.7 delete "salmonella" from the list
things.pop(2)
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']
# ['MOZZARELLA', 'Cinderella', 'salmonella']
# ['MOZZARELLA', 'Cinderella']

# %%
#9.1 Define a function called good() that returns the following list: ['Harry', 'Ron', 'Hermione'].

def good():
    good_list = ['Harry', 'Ron', 'Hermione']
    return good_list
#9.2  Define a generator function called get_odds() that returns the odd numbers from range(10). Use a for loop to find and print the third value returned.
def get_odds(first = 1, last = 10):
    number = first
    while number <= last:
        if number %2 != 0:
            yield number
        number += 1
count = 1
for x in get_odds():
    if count == 3:
        print(x)
    count += 1
# Out:
# 5
